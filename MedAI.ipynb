# %%
# Imports for loading environment variables.
from dotenv import load_dotenv
import os

# %%
# Load environment variables.
load_dotenv()

# Set the model name for our LLMs.
GEMINI_MODEL = "gemini-1.5-flash"

# Store the API key in a variable.
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# %%
# Additional imports for specific chains we'll use.
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains import LLMChain
from langchain.chains.constitutional_ai.base import ConstitutionalChain
from langchain.chains.constitutional_ai.models import ConstitutionalPrinciple
from langchain.prompts import ChatPromptTemplate

# %%
# Install the required packages using pip.
# !pip install langchain langchain-google-genai python-dotenv
# !pip install google-cloud-aiplatform google-auth google-auth-oauthlib google-auth-httplib2 google-api-python-client
# !pip install ChatGoogleGenerativeAI
# !pip install langchain-google-genai
# Install the required packages using pip.



# Create a medical LLM instance using the Gemini model.
llm = ChatGoogleGenerativeAI(
    model = "gemini-1.5-flash",
    temperature=1.0,
    max_output_tokens=1000,
    top_p=1.0,
    google_api_key = GEMINI_API_KEY
)
# Create a prompt template for the LLM.
prompt_template = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a medical assistant."),
        ("human", "{input}"),
        ("assistant", "{output}")
    ]
)
# Create a chain using the LLM and the prompt template.
llm_chain = LLMChain(
    llm=llm,
    prompt=prompt_template
)
# Define a function to get the LLM's response to a medical question.
def get_medical_response(question: str) -> str:
    # Use the LLM chain to get a response from the LLM.
    response = llm_chain.run(input=question)
    return response
# Out:
# Requirement already satisfied: langchain in c:\users\justi\anaconda3\envs\ai\lib\site-packages (0.3.21)
# Requirement already satisfied: langchain-google-genai in c:\users\justi\anaconda3\envs\ai\lib\site-packages (2.1.1)
# Requirement already satisfied: python-dotenv in c:\users\justi\anaconda3\envs\ai\lib\site-packages (1.0.1)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain) (0.3.48)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain) (0.3.7)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain) (0.3.18)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain) (2.10.6)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.16 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain-google-genai) (0.6.17)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.24.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (5.29.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.69.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (4.9)
# Requirement already satisfied: anyio in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain) (3.0.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (0.4.8)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.2.0)
# Requirement already satisfied: google-cloud-aiplatform in c:\users\justi\anaconda3\envs\ai\lib\site-packages (1.87.0)
# Requirement already satisfied: google-auth in c:\users\justi\anaconda3\envs\ai\lib\site-packages (2.38.0)
# Requirement already satisfied: google-auth-oauthlib in c:\users\justi\anaconda3\envs\ai\lib\site-packages (1.2.1)
# Requirement already satisfied: google-auth-httplib2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (0.2.0)
# Requirement already satisfied: google-api-python-client in c:\users\justi\anaconda3\envs\ai\lib\site-packages (2.166.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.24.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-cloud-aiplatform) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0,>=3.20.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-cloud-aiplatform) (5.29.4)
# Requirement already satisfied: packaging>=14.3 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-cloud-aiplatform) (24.2)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=1.32.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-cloud-aiplatform) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-cloud-aiplatform) (3.31.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-cloud-aiplatform) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-cloud-aiplatform) (2.0.7)
# Requirement already satisfied: pydantic<3 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-cloud-aiplatform) (2.10.6)
# Requirement already satisfied: typing-extensions in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-cloud-aiplatform) (4.12.2)
# Requirement already satisfied: docstring-parser<1 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-cloud-aiplatform) (0.16)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-auth) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-auth) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-auth) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: httplib2>=0.19.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-auth-httplib2) (0.22.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.69.2)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.71.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-cloud-storage<3.0.0,>=1.32.0->google-cloud-aiplatform) (1.7.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from httplib2>=0.19.0->google-auth-httplib2) (3.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.4.8)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from pydantic<3->google-cloud-aiplatform) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from pydantic<3->google-cloud-aiplatform) (2.27.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: numpy<3,>=1.14 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from shapely<3.0.0->google-cloud-aiplatform) (1.26.4)
# Requirement already satisfied: six>=1.5 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2024.8.30)
# ERROR: Could not find a version that satisfies the requirement ChatGoogleGenerativeAI (from versions: none)
# ERROR: No matching distribution found for ChatGoogleGenerativeAI
# Requirement already satisfied: langchain-google-genai in c:\users\justi\anaconda3\envs\ai\lib\site-packages (2.1.1)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.16 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain-google-genai) (0.6.17)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.47 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain-google-genai) (0.3.48)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain-google-genai) (2.10.6)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.24.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (5.29.4)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (0.3.18)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (2.27.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.69.2)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (0.23.0)
# Requirement already satisfied: anyio in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (4.2.0)
# Requirement already satisfied: certifi in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (1.0.2)
# Requirement already satisfied: idna in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (3.7)
# Requirement already satisfied: sniffio in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (0.14.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.2.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\justi\anaconda3\envs\ai\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.47->langchain-google-genai) (1.2.0)

# %%
# Import the pipeline function from the transformers library.
# !pip install transformers
import transformers
from transformers import pipeline
# Import the ChatGoogleGenerativeAI class from the langchain_google_genai module.
from langchain_google_genai import ChatGoogleGenerativeAI
# Import the ChatPromptTemplate class from the langchain.prompts module.
from langchain.prompts import ChatPromptTemplate
# Import the LLMChain class from the langchain.chains module.
from langchain.chains import LLMChain
# Use the text-generation parameter for the pipeline and EleutherAI/gpt-neo-1.3B model. 
generator = pipeline('text-generation', model='EleutherAI/gpt-neo-1.3B')
# Create a prompt template for the LLM.
prompt_template = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a medical assistant."),
        ("human", "{input}"),
        ("assistant", "{output}")
    ]
)
# Create a chain using the LLM and the prompt template.
llm_chain = LLMChain(
    llm=generator,
    prompt=prompt_template
)
# Define a function to get the LLM's response to a medical question.
def get_medical_response(question: str) -> str:
    # Use the LLM chain to get a response from the LLM.
    response = llm_chain.run(input=question)
    return response
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\justi\anaconda3\envs\ai\lib\site-packages\transformers\utils\import_utils.py:1863, in _LazyModule._get_module(self, module_name)
#    1862 try:
# -> 1863     return importlib.import_module("." + module_name, self.__name__)
#    1864 except Exception as e:
#
# File c:\Users\justi\anaconda3\envs\ai\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\justi\anaconda3\envs\ai\lib\site-packages\transformers\pipelines\__init__.py:26
#      25 from ..feature_extraction_utils import PreTrainedFeatureExtractor
# ---> 26 from ..image_processing_utils import BaseImageProcessor
#      27 from ..models.auto.configuration_auto import AutoConfig
#
# File c:\Users\justi\anaconda3\envs\ai\lib\site-packages\transformers\image_processing_utils.py:22
#      21 from .image_processing_base import BatchFeature, ImageProcessingMixin
# ---> 22 from .image_transforms import center_crop, normalize, rescale
#      23 from .image_utils import ChannelDimension, get_image_size
#
# File c:\Users\justi\anaconda3\envs\ai\lib\site-packages\transformers\image_transforms.py:48
#      47 if is_tf_available():
# ---> 48     import tensorflow as tf
#      50 if is_flax_available():
#
# File c:\Users\justi\anaconda3\envs\ai\lib\site-packages\tensorflow\__init__.py:55
#      54 from tensorflow._api.v2 import bitwise
# ---> 55 from tensorflow._api.v2 import compat
#      56 from tensorflow._api.v2 import config
#
# File c:\Users\justi\anaconda3\envs\ai\lib\site-packages\tensorflow\_api\v2\compat\__init__.py:8
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat import v1
#       9 from tensorflow._api.v2.compat import v2
#
# File c:\Users\justi\anaconda3\envs\ai\lib\site-packages\tensorflow\_api\v2\compat\v1\__init__.py:30
#      29 from tensorflow._api.v2.compat.v1 import bitwise
# ---> 30 from tensorflow._api.v2.compat.v1 import compat
#      31 from tensorflow._api.v2.compat.v1 import config
#
# File c:\Users\justi\anaconda3\envs\ai\lib\site-packages\tensorflow\_api\v2\compat\v1\compat\__init__.py:8
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat.v1.compat import v1
#       9 from tensorflow._api.v2.compat.v1.compat import v2
#
# File c:\Users\justi\anaconda3\envs\ai\lib\site-packages\tensorflow\_api\v2\compat\v1\compat\v1\__init__.py:36
#      35 from tensorflow._api.v2.compat.v1 import distributions
# ---> 36 from tensorflow._api.v2.compat.v1 import dtypes
#      37 from tensorflow._api.v2.compat.v1 import errors
#
# File c:\Users\justi\anaconda3\envs\ai\lib\site-packages\tensorflow\_api\v2\compat\v1\dtypes\__init__.py:8
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat.v1.dtypes import experimental
#       9 from tensorflow.python.ops.gen_string_ops import as_string # line: 29
#
# File c:\Users\justi\anaconda3\envs\ai\lib\site-packages\tensorflow\_api\v2\compat\v1\dtypes\experimental\__init__.py:8
#       6 import sys as _sys
# ----> 8 from tensorflow.python.framework.dtypes import float8_e4m3b11fnuz # line: 465
#       9 from tensorflow.python.framework.dtypes import float8_e4m3fn # line: 439
#
# ImportError: cannot import name 'float8_e4m3b11fnuz' from 'tensorflow.python.framework.dtypes' (c:\Users\justi\anaconda3\envs\ai\lib\site-packages\tensorflow\python\framework\dtypes.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Use the text-generation parameter for the pipeline and EleutherAI/gpt-neo-1.3B model.
# ----> 2 from transformers import pipeline
#       4 generator = pipeline('text-generation', model='EleutherAI/gpt-neo-1.3B')
#       6 # Define a function to get the generator's response to a medical question.
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\justi\anaconda3\envs\ai\lib\site-packages\transformers\utils\import_utils.py:1851, in _LazyModule.__getattr__(self, name)
#    1849     value = Placeholder
#    1850 elif name in self._class_to_module.keys():
# -> 1851     module = self._get_module(self._class_to_module[name])
#    1852     value = getattr(module, name)
#    1853 elif name in self._modules:
#
# File c:\Users\justi\anaconda3\envs\ai\lib\site-packages\transformers\utils\import_utils.py:1865, in _LazyModule._get_module(self, module_name)
#    1863     return importlib.import_module("." + module_name, self.__name__)
#    1864 except Exception as e:
# -> 1865     raise RuntimeError(
#    1866         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1867         f" traceback):\n{e}"
#    1868     ) from e
#
# RuntimeError: Failed to import transformers.pipelines because of the following error (look up to see its traceback):
# cannot import name 'float8_e4m3b11fnuz' from 'tensorflow.python.framework.dtypes' (c:\Users\justi\anaconda3\envs\ai\lib\site-packages\tensorflow\python\framework\dtypes.py)

# %%
# Give the model a prompt. 
prompt = "MedAI, I'm sick, I have a runny nose, and a fever, what is it and what do I do?"
# Pass the prompt to the generator
results = generator(prompt, max_length=125, pad_token_id=50256)
# Get the text based on the prompt. 
generated_text = results[0]['generated_text']
# Print the generated text.
print(generated_text)

# %%
# Use the text-generation parameter for the pipeline and EleutherAI/gpt-neo-125m model. 
small_generator = pipeline('text-generation', model='ChatGoogleGenerativeAI')

# %%
# Give the model a prompt. 
prompt = "What are the possible causes for a topical rash?"
# Pass the prompt to the generator. Use `max_length=25`.
new_results = small_generator(prompt, max_length=25, pad_token_id=50256)
# Get the text based on the prompt. 
generated_text = new_results[0]['generated_text']
# Print the generated text.
print(generated_text)

# %%
# Import Pandas 
import pandas as pd

# Create a function to generate the answers based on an input text.
def question_answer(questions, text):
    # Create a list to hold the data that will be added to the DataFrame.
    data = []
    # Use a for loop to iterate through the questions.
    for question in questions:
        # Pass the question and text to the initialized question_answerer. 
        result = question_answerer(question=question, context=text)
        # Retrieve the question, answer, the score, the starting 
        # and ending of where the answer is located in the text.
        data.append([question, result['answer'], result['score'], result['start'], result['end']])
    # Create a DataFrame from the data with appropriate columns. 
    df = pd.DataFrame(data, columns=["Question", "Answer", "Score", "Starting Position", "Ending Position"])
    # Return the DataFrame
    return df
